# %% [markdown]
# hac 1: FOREIGN OBJECT RETAINED AFTER SURGERY
# hac 2: AIR EMBOLISM
# hac 3: BLOOD INCOMPATABILITY
# hac 4: STAGE III and IV PRESSURE ULCERS
# hac 5: FALLS AND TRAUMA
# hac 6: CATHETHER-ASSOCIATED URINARY TRACT INFECTION (UTI)
# hac 7: VASCULAR CATHETHER-ASSOCIATED INFECTION
# hac 8: SURGICAL SITE INFECTION-MEDIASTINITIS AFTER CORONARY BYPASS GRAFT (CABG)
# hac 9: MANIFESTATIONS OF POOR GLYCEMIC CONTROL
# hac 10: DEEP VEIN THROMBOSIS (DTV) / PULMONARY EMBOLISM (PE) WITH TOTAL KNEE OR HIP REPLACEMENT
# hac 11: SURGICAL SITE INFECTION - BARIATRIC SURGERY
# hac 12: SURGICAL SITE INFECTION - CERTAIN ORTHOPEDIC PROCEDURES OF SPINE, SHOULDER AND ELBOW
# hac 13: SURGICAL SITE INFECTION (SSI) FOLLOWING CARDIAC IMPLANTABLE ELECTRONIC DEVICE (CIED) PROCEDURES
# hac 14: IATROGENIC PNEUMOTHORAX W/ VENOUS CATHETERIZATION
#
# 1-3 are not in this sample. All are pretty low incidence. might be worth looking for presence of any of the HACs instead of looking at them individually
#
# Source: https://www.cms.gov/Medicare/Medicare-Fee-for-Service-Payment/HospitalAcqCond/Hospital-Acquired_Conditions

# %%
var = 'cms_hac_6'

# %%
col_list=list(df.columns)

# %%
def list_sorter(i):
    return len(df[i].value_counts())

col_list.sort(key=list_sorter, reverse=True)

# %%
dummy_columns=list(df_dummy_all.columns)

dummy_columns.remove('DISCWT')
dummy_columns.remove('HOSP_NIS')
dummy_columns.remove('NIS_STRATUM')

# %% [markdown]
# for i in dummy_columns:
#     sns.countplot(data=df_dummy, x=i)
#     plt.show()

# %%
dummy_list = list(dummy_columns)
hac_list = dummy_list[21:32]

# %%
print("total number of patients: " + str(len(df.index)))
print()
for hac in hac_list:
    print(hac + " count = "+ str(df_dummy_all.loc[:,hac].sum()))
# Out:
# total number of patients: 17484
#
# cms_hac_4 count = 44.0
# cms_hac_5 count = 136.0
# cms_hac_6 count = 1443.0
# cms_hac_7 count = 8.0
# cms_hac_8 count = 10.0
# cms_hac_9 count = 14.0
# cms_hac_10 count = 459.0
# cms_hac_11 count = 387.0
# cms_hac_12 count = 2.0
# cms_hac_13 count = 3.0
# cms_hac_14 count = 81.0

# %%
sns.set_context("paper")
sns.set_theme(style="darkgrid")
palette = sns.set_palette('deep')

g = sns.PairGrid(data=df_dummy_all, x_vars=var,
                 y_vars=dummy_list, height=5, aspect=2)
g.map(sns.barplot, palette=palette, alpha=.69, capsize=.1)
g.tightlayout=True
sns.despine(fig=g.fig, left=True)

# %%
df_corr=df_dummy_all.corr()

sns.set(rc={'figure.figsize':(200,10)})

sns.set_context('poster')

df_corr = df_corr.sort_values(var, ascending=False, axis=0)

df_corr = df_corr[df_corr[var]>0]

y_values=df_corr[var]

y_values = y_values.drop([var, 'any_hac', 'cms_hac_4',
 'cms_hac_6'])

x_axis_labels = df_corr[var].index

x_axis_labels = x_axis_labels.drop([var, 'any_hac', 'cms_hac_4',
 'cms_hac_6'])

x_axis_labels = x_axis_labels.to_numpy()

sns.barplot(x=x_axis_labels, y=y_values, palette='icefire_r', )
# Out:
# <AxesSubplot:ylabel='cms_hac_6'>

# %%
df_corr=df_dummy_all.corr()

sns.set(rc={'figure.figsize':(200,10)})

sns.set_context('poster')

df_corr = df_corr.sort_values(var, ascending=True, axis=0)

df_corr = df_corr[df_corr[var]<=0]

y_values=df_corr[var]

y_values = y_values

x_axis_labels = df_corr[var].index

x_axis_labels = x_axis_labels

x_axis_labels = x_axis_labels.to_numpy()

sns.barplot(x=x_axis_labels, y=y_values, palette='icefire', )
# Out:
# <AxesSubplot:ylabel='cms_hac_6'>

# %%
list(df_dummy_all.columns)
# Out:
# ['DISCWT',
#  'HOSP_NIS',
#  'NIS_STRATUM',
#  'crani',
#  'AIDS',
#  'ALCOHOL',
#  'ARTH',
#  'CBVD',
#  'DEMENTIA',
#  'DEPRESS',
#  'DIAB_UNCX',
#  'DIAB_CX',
#  'DRUG_ABUSE',
#  'HTN_CX',
#  'HTN_UNCX',
#  'LIVER_SEV',
#  'LUNG_CHRONIC',
#  'OBESE',
#  'PARALYSIS',
#  'PERIVASC',
#  'RENLFL_SEV',
#  'THYROID_HYPO',
#  'THYROID_OTH',
#  'VALVE',
#  'cms_hac_4',
#  'cms_hac_5',
#  'cms_hac_6',
#  'cms_hac_7',
#  'cms_hac_8',
#  'cms_hac_9',
#  'cms_hac_10',
#  'cms_hac_11',
#  'cms_hac_12',
#  'cms_hac_13',
#  'cms_hac_14',
#  'age_cat_0.0',
#  'age_cat_1.0',
#  'age_cat_2.0',
#  'age_cat_3.0',
#  'age_cat_4.0',
#  'age_cat_5.0',
#  'age_cat_6.0',
#  'age_cat_7.0',
#  'age_cat_8.0',
#  'age_cat_9.0',
#  'ed_codes_0.0',
#  'ed_codes_1.0',
#  'AMONTH_1.0',
#  'AMONTH_2.0',
#  'AMONTH_3.0',
#  'AMONTH_4.0',
#  'AMONTH_5.0',
#  'AMONTH_6.0',
#  'AMONTH_7.0',
#  'AMONTH_8.0',
#  'AMONTH_9.0',
#  'AMONTH_10.0',
#  'AMONTH_11.0',
#  'AMONTH_12.0',
#  'AMONTH_nan',
#  'PAY1_1.0',
# ...

# %%
diag_list = [var, 'age_cat_0.0',
 'age_cat_1.0',
 'age_cat_2.0',
 'age_cat_3.0',
 'age_cat_4.0',
 'age_cat_5.0',
 'age_cat_6.0',
 'age_cat_7.0',
 'age_cat_8.0',
 'age_cat_9.0',
 'ed_codes_0.0',
 'ed_codes_1.0',
 'AMONTH_1.0',
 'AMONTH_2.0',
 'AMONTH_3.0',
 'AMONTH_4.0',
 'AMONTH_5.0',
 'AMONTH_6.0',
 'AMONTH_7.0',
 'AMONTH_8.0',
 'AMONTH_9.0',
 'AMONTH_10.0',
 'AMONTH_11.0',
 'AMONTH_12.0',
 'AMONTH_nan',
 'PAY1_1.0',
 'PAY1_2.0',
 'PAY1_3.0',
 'PAY1_4.0',
 'PAY1_5.0',
 'PAY1_6.0',
 'PAY1_nan',
 'APRDRG_Risk_Mortality_1.0',
 'APRDRG_Risk_Mortality_2.0',
 'APRDRG_Risk_Mortality_3.0',
 'APRDRG_Risk_Mortality_4.0',
 'RACE_1.0',
 'RACE_2.0',
 'RACE_3.0',
 'RACE_4.0',
 'RACE_5.0',
 'RACE_6.0',
 'RACE_nan',
 'YEAR_2016.0',
 'YEAR_2017.0',
 'ZIPINC_QRTL_1.0',
 'ZIPINC_QRTL_2.0',
 'ZIPINC_QRTL_3.0',
 'ZIPINC_QRTL_4.0',
 'ZIPINC_QRTL_nan',
 'HOSP_BEDSIZE_1.0',
 'HOSP_BEDSIZE_2.0',
 'HOSP_BEDSIZE_3.0',
 'HOSP_LOCTEACH_1.0',
 'HOSP_LOCTEACH_2.0',
 'HOSP_LOCTEACH_3.0',
 'HOSP_REGION_1.0',
 'HOSP_REGION_2.0',
 'HOSP_REGION_3.0',
 'HOSP_REGION_4.0',
 'FEMALE_0.0',
 'FEMALE_1.0',
 'FEMALE_nan']

# %%
sns.pairplot(df_dummy_all, x_vars=diag_list, palette='icefire', y_vars=diag_list, kind='reg', corner=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-282-19ba348acb96> in <module>
# ----> 1 sns.pairplot(df_dummy_all, x_vars=diag_list, palette='icefire', y_vars=diag_list, kind='reg', corner=True)
#
# ~/miniforge3/envs/tf2/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/miniforge3/envs/tf2/lib/python3.8/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2033     elif kind == "reg":
#    2034         from .regression import regplot  # Avoid circular import
# -> 2035         plotter(regplot, **plot_kws)
# ...

# %%
sns.set(rc={'figure.figsize':(20,20)})

# %% [markdown]
# sns.catplot(x='APRDRG_Risk_Mortality', y = 'cms_hac_5', kind='bar', data=df, palette='magma')

# %% [markdown]
# sns.catplot(x='PAY1', y='cms_hac_5', kind='bar', errwidth=1, capsize=.15, data=df, palette='magma')

# %% [markdown]
# sns.catplot(x='RACE', y='cms_hac_5', kind='bar', errwidth=1, capsize=.15, data=df, palette='magma')

# %% [markdown]
# sns.catplot(x='FEMALE', y='cms_hac_5', kind='bar', errwidth=1, capsize=.15, data=df, palette='magma')

# %% [markdown]
# sns.catplot(x='AMONTH', y='cms_hac_5', kind='bar', aspect=2, errwidth=1, capsize=.15, data=df, palette='magma')

# %% [markdown]
# sns.catplot(x='YEAR', y='cms_hac_5', kind='bar', errwidth=1, capsize=.15, data=df, palette='magma')

# %% [markdown]
# sns.catplot(x='ZIPINC_QRTL', y='cms_hac_5', kind='bar', errwidth=1, capsize=.15, data=df, palette='magma')

# %% [markdown]
# sns.catplot(x='HOSP_BEDSIZE', y='cms_hac_5', kind='bar', errwidth=1, capsize=.15, data=df, palette='magma')

# %% [markdown]
# sns.catplot(x='HOSP_LOCTEACH', y='cms_hac_5', kind='bar', errwidth=1, capsize=.15, data=df, palette='magma')

# %% [markdown]
# sns.catplot(x='HOSP_REGION', y='cms_hac_5', kind='bar', errwidth=1, capsize=.15, data=df, palette='magma')

# %% [markdown]
# sns.catplot(x='age_cat', y='cms_hac_5', kind='bar', errwidth=1, capsize=.15, data=df, palette='magma')

# %%
cat_list = ['AMONTH', 'FEMALE',
       'PAY1', 'RACE', 'YEAR', 'ZIPINC_QRTL', 'APRDRG_Risk_Mortality',
       'HOSP_BEDSIZE', 'HOSP_LOCTEACH', 'HOSP_REGION', 'age_cat', 'ed_codes']

# %%
sns.set_palette('hls', desat=.7, n_colors=25)
for i in cat_list:
    sns.catplot(x=i, kind = 'bar', y=var, errwidth=1, capsize=.15, data=df )
    plt.show()

# %% [markdown]
# pivot = df.pivot_table( 'cms_hac_5', 'RACE', 'HOSP_LOCTEACH', aggfunc=np.mean,)

# %% [markdown]
# pivot

# %% [markdown]
# pivot[2][3]

# %% [markdown]
# center=df.loc[:,'RACE']

# %% [markdown]
# center

# %% [markdown]
# pivot = df.pivot_table( 'crani', 'HOSP_LOCTEACH', 'RACE', aggfunc=np.mean, observed=True)
# sns.heatmap(pivot, linewidths=0.69, square=True, center=pivot[2][3], annot=True, linecolor='white', cbar=True, cmap='vlag')
# plt.ylim(0, len(pivot.index))
# plt.xlim(0, len(pivot.columns))
# plt.show()
# #sns.heatmap(df[non_cm_list].astype(float).corr(),linewidths=0.5,vmax=1.0, square=True, center = 0,linecolor='white', cmap=palette, cbar=True, annot=True)

# %% [markdown]
# pivot = df.pivot_table( 'cms_hac_5', 'HOSP_LOCTEACH', 'RACE', aggfunc=np.mean, observed=True)
# sns.heatmap(pivot, linewidths=0.69, square=True, annot=True, linecolor='white', cbar=True, cmap='vlag')
# plt.ylim(0, len(pivot.index))
# plt.xlim(0, len(pivot.columns))
# plt.show()
# #sns.heatmap(df[non_cm_list].astype(float).corr(),linewidths=0.5,vmax=1.0, square=True, center = 0,linecolor='white', cmap=palette, cbar=True, annot=True)

# %% [markdown]
# pivot = df.pivot_table( 'crani', 'ZIPINC_QRTL', 'RACE', aggfunc=np.mean, observed=True)
# pivot

# %% [markdown]
# pivot[2][3]

# %% [markdown]
# len(pivot.columns)

# %% [markdown]
# len(pivot.index)

# %% [markdown]
# sns.heatmap(pivot, linewidths=0.69, square=True, center=pivot[2][1], annot=True, linecolor='white', cbar=True, cmap='vlag')
# plt.ylim(0, len(pivot.index))
# plt.xlim(0, len(pivot.columns))
# plt.show()
# #sns.heatmap(df[non_cm_list].astype(float).corr(),linewidths=0.5,vmax=1.0, square=True, center = 0,linecolor='white', cmap=palette, cbar=True, annot=True)

# %% [markdown]
# pivot = df.pivot_table( 'crani', 'APRDRG_Risk_Mortality', 'RACE', aggfunc=np.mean, observed=True)
#
# sns.heatmap(pivot, linewidths=0.69, square=True, center=pivot[2][1], annot=True, linecolor='white', cbar=True, cmap='vlag')
# plt.ylim(0, len(pivot.index))
# plt.xlim(0, len(pivot.columns))
# plt.show()
# #sns.heatmap(df[non_cm_list].astype(float).corr(),linewidths=0.5,vmax=1.0, square=True, center = 0,linecolor='white', cmap=palette, cbar=True, annot=True)

# %% [markdown]
# pivot = df.pivot_table( 'crani', 'HOSP_BEDSIZE', 'RACE', aggfunc=np.mean, observed=True)
#
# sns.heatmap(pivot, linewidths=0.69, square=True, center=pivot[2][3], annot=True, linecolor='white', cbar=True, cmap='vlag')
# plt.ylim(0, len(pivot.index))
# plt.xlim(0, len(pivot.columns))
# plt.show()
# #sns.heatmap(df[non_cm_list].astype(float).corr(),linewidths=0.5,vmax=1.0, square=True, center = 0,linecolor='white', cmap=palette, cbar=True, annot=True)

# %% [markdown]
# pivot = df.pivot_table( 'crani', 'HOSP_LOCTEACH', 'RACE', aggfunc=np.mean, observed=True)
#
# sns.heatmap(pivot, linewidths=0.69, square=True, center=pivot[2][1], annot=True, linecolor='white', cbar=True, cmap='vlag')
# plt.ylim(0, len(pivot.index))
# plt.xlim(0, len(pivot.columns))
#
# plt.show()
# #sns.heatmap(df[non_cm_list].astype(float).corr(),linewidths=0.5,vmax=1.0, square=True, center = 0,linecolor='white', cmap=palette, cbar=True, annot=True)

# %% [markdown]
# pivot = df.pivot_table( 'crani', 'HOSP_REGION', 'RACE', aggfunc=np.mean, observed=True)
#
# sns.heatmap(pivot, linewidths=0.69, square=True, center=pivot[2][3], annot=True, linecolor='white', cbar=True, cmap='vlag')
# plt.ylim(0, len(pivot.index))
# plt.xlim(0, len(pivot.columns))
# plt.show()
# #sns.heatmap(df[non_cm_list].astype(float).corr(),linewidths=0.5,vmax=1.0, square=True, center = 0,linecolor='white', cmap=palette, cbar=True, annot=True)

# %% [markdown]
# pivot = df.pivot_table( 'crani', 'age_cat', 'RACE', aggfunc=np.mean, observed=True)
#
# sns.heatmap(pivot, linewidths=0.69, square=True, center=pivot[2][0], annot=True, linecolor='white', cbar=True, cmap='vlag')
# plt.ylim(0, len(pivot.index))
# plt.xlim(0, len(pivot.columns))
# plt.show()
# #sns.heatmap(df[non_cm_list].astype(float).corr(),linewidths=0.5,vmax=1.0, square=True, center = 0,linecolor='white', cmap=palette, cbar=True, annot=True)

# %%
df.columns
# Out:
# Index(['AMONTH', 'DISCWT', 'FEMALE', 'HOSP_NIS', 'NIS_STRATUM', 'PAY1', 'RACE',
#        'YEAR', 'ZIPINC_QRTL', 'APRDRG_Risk_Mortality', 'HOSP_BEDSIZE',
#        'HOSP_LOCTEACH', 'HOSP_REGION', 'crani', 'AIDS', 'ALCOHOL', 'ARTH',
#        'CBVD', 'DEMENTIA', 'DEPRESS', 'DIAB_UNCX', 'DIAB_CX', 'DRUG_ABUSE',
#        'HTN_CX', 'HTN_UNCX', 'LIVER_SEV', 'LUNG_CHRONIC', 'OBESE', 'PARALYSIS',
#        'PERIVASC', 'RENLFL_SEV', 'THYROID_HYPO', 'THYROID_OTH', 'VALVE',
#        'cms_hac_4', 'cms_hac_5', 'cms_hac_6', 'cms_hac_7', 'cms_hac_8',
#        'cms_hac_9', 'cms_hac_10', 'cms_hac_11', 'cms_hac_12', 'cms_hac_13',
#        'cms_hac_14', 'age_cat', 'ed_codes'],
#       dtype='object')

# %%
proba_list = [ 'FEMALE', 'AMONTH','PAY1','RACE', 'YEAR', 'ZIPINC_QRTL', 'APRDRG_Risk_Mortality', 'HOSP_BEDSIZE','HOSP_LOCTEACH', 'HOSP_REGION', 'crani', 'age_cat', 'ed_codes']

# %%
sns.set(rc={'figure.figsize':(10,10)})

# %%
palette = sns.color_palette("Set2", 2,  desat=.6)

for i in proba_list:
    sns.histplot(df, x=i, hue=var, discrete=True, stat='probability', palette=palette, multiple='fill' )
    plt.xticks(ticks=range(df[i].min().astype(int), df[i].max().astype(int)+1))
    plt.show()

# %% [markdown]
# palette = sns.color_palette("husl", 2, desat=.4)
#
# for i in proba_list:
#     sns.histplot(df, x=i, hue=var, discrete=True, stat='probability', palette=palette, multiple='dodge' )
#     plt.xticks(ticks=range(df[i].min().astype(int), df[i].max().astype(int)+1))
#     plt.show()

# %% [markdown]
# palette = sns.set_palette("magma", 2, .7)
#
#
# sns.catplot(x='RACE', y='crani', kind='point', data=df, palette=palette)
